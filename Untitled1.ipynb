# %% [markdown]
# <a href="https://colab.research.google.com/github/Avi0906/Python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Day 3 With PANDAS

# %%
import pandas as pd

# %%
#import the dataset
stats=pd.read_csv("/content/DemographicData.csv")

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
len(stats)
# Out:
# 195

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
len (stats.columns)
# Out:
# 5

# %%
stats.head()
# Out:
#             Countryname Countrycode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            Incomegroup  New Column
# 0          High income    7.702070
# 1           Low income    0.167362
# 2  Upper middle income    0.415353
# 3  Upper middle income    4.442028
# 4          High income    7.968127

# %%
stats.to_excel("output.xlsx")

# %%
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
stats.columns=['Countryname', 'Countrycode', 'Birthrate', 'Internetusers', 'Incomegroup']

# %%
stats
# Out:
#               Countryname Countrycode  Birthrate  Internetusers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              Incomegroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
#rows
stats[9:12]
# Out:
#    Countryname Countrycode  Birthrate  Internetusers          Incomegroup
# 9      Austria         AUT      9.400        80.6188          High income
# 10  Azerbaijan         AZE     18.300        58.7000  Upper middle income
# 11     Burundi         BDI     44.151         1.3000           Low income

# %%
#column
stats.columns[2:4]
# Out:
# Index(['Birthrate', 'Internetusers'], dtype='object')

# %%
stats[:9]
# Out:
#             Countryname Countrycode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
# 8             Australia         AUS     13.200           83.0
#
#            Incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income

# %%
stats[99:]
# Out:
#           Countryname Countrycode  Birthrate  Internetusers  \
# 99            Liberia         LBR     35.521            3.2
# 100             Libya         LBY     21.425           16.5
# 101         St. Lucia         LCA     15.430           46.2
# 102     Liechtenstein         LIE      9.200           93.8
# 103         Sri Lanka         LKA     17.863           21.9
# ..                ...         ...        ...            ...
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              Incomegroup
# 99            Low income
# 100  Upper middle income
# 101  Upper middle income
# 102          High income
# 103  Lower middle income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# ...

# %%
stats[::-1]
# Out:
#               Countryname Countrycode  Birthrate  Internetusers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              Incomegroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
#Column Subsettings
stats['Countryname'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: Countryname, dtype: object

# %%
stats[['Countryname', 'Birthrate']].head()
# Out:
#             Countryname  Birthrate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
#Dataframe.column.funtion()
stats.Countrycode.head()
# Out:
# 0    ABW
# 1    AFG
# 2    AGO
# 3    ALB
# 4    ARE
# Name: Countrycode, dtype: object

# %%
#Subsettings Rows & Columns
stats[3:9][['Countryname','Birthrate']]
# Out:
#             Countryname  Birthrate
# 3               Albania     12.877
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447
# 8             Australia     13.200

# %%
stats[['Countryname','Birthrate']][3:9]
# Out:
#             Countryname  Birthrate
# 3               Albania     12.877
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447
# 8             Australia     13.200

# %%
result = stats.Internetusers/stats.Birthrate

# %%
result.head()
# Out:
# 0    7.702070
# 1    0.167362
# 2    0.415353
# 3    4.442028
# 4    7.968127
# dtype: float64

# %%
stats['New Column']= stats.Internetusers/stats.Birthrate

# %%
stats.head()
# Out:
#             Countryname Countrycode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            Incomegroup  New Column
# 0          High income    7.702070
# 1           Low income    0.167362
# 2  Upper middle income    0.415353
# 3  Upper middle income    4.442028
# 4          High income    7.968127

# %%
newstats = stats.drop('New Column',1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
newstats.head()
# Out:
#             Countryname Countrycode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            Incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Filtering Data Frame
filter =stats.Internetusers <2

# %%
filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: Internetusers, Length: 195, dtype: bool

# %%
stats[filter]
# Out:
#       Countryname Countrycode  Birthrate  Internetusers          Incomegroup  \
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income
#
#      New Column
# 11     0.029444
# 52     0.025862
# 55     0.057707
# 64     0.042853
# 117    0.088305
# 127    0.034232
# 154    0.046285
# 156    0.034176
# 172    0.030765

# %%
stats[stats.Internetusers <2]
# Out:
#       Countryname Countrycode  Birthrate  Internetusers          Incomegroup  \
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income
#
#      New Column
# 11     0.029444
# 52     0.025862
# 55     0.057707
# 64     0.042853
# 117    0.088305
# 127    0.034232
# 154    0.046285
# 156    0.034176
# 172    0.030765

# %%
stats [(stats.Internetusers <2) & (stats.Birthrate >40)]
# Out:
#     Countryname Countrycode  Birthrate  Internetusers Incomegroup  New Column
# 11      Burundi         BDI     44.151            1.3  Low income    0.029444
# 127       Niger         NER     49.661            1.7  Low income    0.034232
# 156     Somalia         SOM     43.891            1.5  Low income    0.034176

# %%
#Getting Unique Categories
stats.Incomegroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
#Accessing Indivdual Elements

# %%
stats.iat[1,4]
# Out:
# 'Low income'

# %%
stats.iat[1,1]
# Out:
# 'AFG'

# %%
stats.at[2,'Internetusers']
# Out:
# 19.1

# %%
subset1=stats [::9]

# %%
subset1
# Out:
#           Countryname Countrycode  Birthrate  Internetusers  \
# 0               Aruba         ABW     10.244        78.9000
# 9             Austria         AUT      9.400        80.6188
# 18       Bahamas, The         BHS     15.339        72.0000
# 27             Bhutan         BTN     18.134        29.9000
# 36        Congo, Rep.         COG     37.011         6.6000
# 45            Germany         DEU      8.500        84.1700
# 54            Estonia         EST     10.300        79.4000
# 63              Ghana         GHA     33.131        12.3000
# 72               Guam         GUM     17.389        65.4000
# 81            Ireland         IRL     15.000        78.2477
# 90         Kazakhstan         KAZ     22.730        54.0000
# 99            Liberia         LBR     35.521         3.2000
# 108  Macao SAR, China         MAC     11.256        65.8000
# 117           Myanmar         MMR     18.119         1.6000
# 126     New Caledonia         NCL     17.000        66.0000
# ...

# %%
###Introduction to SEABORN
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=8,8
import warnings
warnings.filterwarnings('ignore')

# %%
#Distribution
sns.distplot(stats['Internetusers'])

# %%
sns.distplot(stats['Internetusers'],bins=40)

# %%
#Boxplot
visualbox1 = sns.boxplot(data=stats, x='Incomegroup', y='Birthrate')

# %%
visual3 = sns.lmplot(data=stats, x='Internetusers', y='Birthrate')

# %%
visual7= sns.distplot(stats['Birthrate'], bins=10)

# %%
visual3 = sns.lmplot(data=stats, x='Internetusers', y='Birthrate', fit_reg = False)

# %%
visual3 = sns.lmplot(data=stats, x='Internetusers', y='Birthrate', fit_reg = False, hue = 'Incomegroup')

# %%
visual3 = sns.lmplot(data=stats, x='Internetusers', y='Birthrate', fit_reg = False, hue = 'Incomegroup', size=7, aspect =2)

# %%
visual3 = sns.lmplot(data=stats, x='Internetusers', y='Birthrate', fit_reg = False, hue = 'Incomegroup', size=7, aspect =2, scatter_kws={'s':90})
